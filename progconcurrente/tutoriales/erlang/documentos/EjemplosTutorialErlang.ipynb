# %% [markdown]
# # **Lenguajes de Programación - Tutorial Erlang**
#
# # Ejemplos
#
# Autores:
# *   Julián Alexander Manosalva Manrique
# *   Juan Sebastián Pachón Carvajal
# *   David Alexander Zambrano Bohórquez

# %%
# !!apt install erlang
# Out:
# ['',
#  'Reading package lists... 0%',
#  '',
#  'Reading package lists... 0%',
#  '',
#  'Reading package lists... 0%',
#  '',
#  'Reading package lists... 4%',
#  '',
#  'Reading package lists... 4%',
#  '',
#  'Reading package lists... 4%',
#  '',
#  'Reading package lists... 4%',
#  '',
#  'Reading package lists... 28%',
#  '',
#  'Reading package lists... 43%',
#  '',
#  'Reading package lists... 43%',
#  '',
#  'Reading package lists... 44%',
#  '',
#  'Reading package lists... 44%',
#  '',
#  'Reading package lists... 55%',
#  '',
#  'Reading package lists... 55%',
#  '',
#  'Reading package lists... 64%',
#  '',
#  'Reading package lists... 64%',
#  '',
#  'Reading package lists... 68%',
#  '',
#  'Reading package lists... 68%',
#  '',
#  'Reading package lists... 68%',
#  '',
#  'Reading package lists... 68%',
#  '',
#  'Reading package lists... 69%',
#  '',
#  'Reading package lists... 69%',
#  '',
#  'Reading package lists... 69%',
#  '',
#  'Reading package lists... 69%',
#  '',
#  'Reading package lists... 69%',
#  '',
#  'Reading package lists... 78%',
#  '',
#  'Reading package lists... 78%',
#  '',
#  'Reading package lists... 86%',
#  '',
#  'Reading package lists... 86%',
#  '',
#  'Reading package lists... 90%',
#  '',
#  'Reading package lists... 90%',
#  '',
#  'Reading package lists... 90%',
#  '',
#  'Reading package lists... 90%',
#  '',
#  'Reading package lists... 91%',
#  '',
#  'Reading package lists... 91%',
#  '',
#  'Reading package lists... 94%',
#  '',
#  'Reading package lists... 94%',
#  '',
#  'Reading package lists... 94%',
#  '',
#  'Reading package lists... 94%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 98%',
#  '',
#  'Reading package lists... 99%',
#  '',
#  'Reading package lists... 99%',
#  '',
#  'Reading package lists... Done',
#  '',
#  'Building dependency tree... 0%',
#  '',
#  'Building dependency tree... 0%',
#  '',
#  'Building dependency tree... 50%',
#  '',
#  'Building dependency tree... 50%',
#  '',
#  'Building dependency tree... 88%',
#  '',
#  'Building dependency tree       ',
#  '',
#  'Reading state information... 0%',
#  '',
#  'Reading state information... 0%',
#  '',
#  'Reading state information... Done',
#  'The following additional packages will be installed:',
#  '  accountsservice acl apg apport apport-symptoms aptdaemon aptdaemon-data',
#  '  aspell aspell-en at-spi2-core avahi-daemon avahi-utils bind9-host bind9-libs',
#  '  bluez bolt bubblewrap cheese-common colord colord-data cracklib-runtime crda',
#  '  cups-pk-helper dbus-x11 dconf-cli desktop-file-utils dictionaries-common',
#  '  dns-root-data dnsmasq-base docbook-xml emacsen-common enchant-2 erlang-asn1',
#  '  erlang-base erlang-common-test erlang-crypto erlang-debugger erlang-dev',
#  '  erlang-dialyzer erlang-diameter erlang-edoc erlang-eldap erlang-erl-docgen',
#  '  erlang-et erlang-eunit erlang-examples erlang-ftp erlang-inets',
#  '  erlang-jinterface erlang-megaco erlang-mnesia erlang-mode erlang-observer',
#  '  erlang-odbc erlang-os-mon erlang-parsetools erlang-public-key erlang-reltool',
#  '  erlang-runtime-tools erlang-snmp erlang-src erlang-ssh erlang-ssl',
#  '  erlang-syntax-tools erlang-tftp erlang-tools erlang-wx erlang-xmerl',
#  '  evolution-data-server evolution-data-server-common fprintd gcr gdm3',
#  '  geoclue-2.0 gettext-base gir1.2-accountsservice-1.0 gir1.2-atk-1.0',
#  '  gir1.2-atspi-2.0 gir1.2-freedesktop gir1.2-gck-1 gir1.2-gcr-3',
#  '  gir1.2-gdesktopenums-3.0 gir1.2-gdkpixbuf-2.0 gir1.2-gdm-1.0',
#  '  gir1.2-geoclue-2.0 gir1.2-gnomebluetooth-1.0 gir1.2-gnomedesktop-3.0',
#  '  gir1.2-graphene-1.0 gir1.2-gtk-3.0 gir1.2-gweather-3.0 gir1.2-ibus-1.0',
#  '  gir1.2-json-1.0 gir1.2-mutter-6 gir1.2-nm-1.0 gir1.2-nma-1.0',
#  '  gir1.2-notify-0.7 gir1.2-pango-1.0 gir1.2-polkit-1.0 gir1.2-rsvg-2.0',
#  '  gir1.2-secret-1 gir1.2-soup-2.4 gir1.2-upowerglib-1.0 gir1.2-vte-2.91 gjs',
#  '  gkbd-capplet gnome-control-center gnome-control-center-data',
#  '  gnome-control-center-faces gnome-desktop3-data gnome-keyring',
#  '  gnome-keyring-pkcs11 gnome-menus gnome-online-accounts gnome-session-bin',
#  '  gnome-session-common gnome-settings-daemon gnome-settings-daemon-common',
#  '  gnome-shell gnome-shell-common gnome-startup-applications gnome-user-docs',
#  '  gstreamer1.0-clutter-3.0 gstreamer1.0-gl gstreamer1.0-plugins-base',
#  '  gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x',
#  '  hunspell-en-us ibus ibus-data ibus-gtk ibus-gtk3 iio-sensor-proxy im-config',
#  '  ippusbxd iptables iw javascript-common keyboard-configuration',
#  '  language-selector-common language-selector-gnome libaa1 libaccountsservice0',
#  '  libappindicator3-1 libasound2-plugins libaspell15 libavahi-core7',
#  '  libavahi-glib1 libbluetooth3 libcamel-1.2-62 libcanberra-gtk3-0',
#  '  libcanberra-gtk3-module libcanberra-pulse libcdparanoia0 libcheese-gtk25',
#  '  libcheese8 libclutter-1.0-0 libclutter-1.0-common libclutter-gst-3.0-0',
#  '  libclutter-gtk-1.0-0 libcogl-common libcogl-pango20 libcogl-path20 libcogl20',
#  '  libcolord-gtk1 libcolorhug2 libcrack2 libdaemon0 libdbusmenu-glib4',
#  '  libdbusmenu-gtk3-4 libdv4 libebackend-1.2-10 libebook-1.2-20',
#  '  libebook-contacts-1.2-3 libecal-2.0-1 libedata-book-1.2-26',
#  '  libedata-cal-2.0-1 libedataserver-1.2-24 libedataserverui-1.2-2',
#  '  libenchant-2-2 libfontenc1 libfprint-2-2 libgail-common libgail18 libgck-1-0',
#  '  libgcr-base-3-1 libgcr-ui-3-1 libgdata-common libgdata22 libgdm1',
#  '  libgee-0.8-2 libgeoclue-2-0 libgeocode-glib0 libgjs0g libgnome-autoar-0-0',
#  '  libgnome-bluetooth13 libgnome-desktop-3-19 libgnomekbd-common libgnomekbd8',
#  '  libgoa-1.0-0b libgoa-1.0-common libgoa-backend-1.0-1 libgraphene-1.0-0',
#  '  libgsound0 libgssdp-1.2-0 libgstreamer-gl1.0-0',
#  '  libgstreamer-plugins-good1.0-0 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common',
#  '  libgtop-2.0-11 libgtop2-common libgupnp-1.2-0 libgupnp-av-1.0-2',
#  '  libgupnp-dlna-2.0-3 libgusb2 libgweather-3-16 libgweather-common',
#  '  libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0 libibus-1.0-5 libical3',
#  '  libidn11 libieee1284-3 libimobiledevice6 libip6tc2 libjansson4',
#  '  libjavascriptcoregtk-4.0-18 libjs-jquery libjs-jquery-metadata',
#  '  libjs-jquery-tablesorter libldb2 liblocale-gettext-perl libmaxminddb0',
#  '  libmbim-glib4 libmbim-proxy libmediaart-2.0-0 libmm-glib0 libmozjs-68-0',
#  '  libmutter-6-0 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0',
#  '  libnftnl11 libnl-genl-3-200 libnm0 libnma0 libnotify4 libnss-mdns',
#  '  libpam-fprintd libpam-gnome-keyring libpangoxft-1.0-0 libpcap0.8 libpci3',
#  '  libphonenumber7 libplist3 libpulse-mainloop-glib0 libpulsedsp',
#  '  libpwquality-common libpwquality1 libqmi-glib5 libqmi-proxy',
#  '  librygel-core-2.6-2 librygel-db-2.6-2 librygel-renderer-2.6-2',
#  '  librygel-server-2.6-2 libsane libsane-common libsbc1 libsctp1 libsecret-1-0',
#  '  libsecret-common libshout3 libsmbclient libsnapd-glib1 libsnmp-base',
#  '  libsnmp35 libspeexdsp1 libstartup-notification0 libtag1v5 libtag1v5-vanilla',
#  '  libtalloc2 libteamdctl0 libtevent0 libtext-iconv-perl libudev1 libudisks2-0',
#  '  libupower-glib3 libusbmuxd6 libv4l-0 libv4lconvert0 libvisual-0.4-0',
#  '  libvte-2.91-0 libvte-2.91-common libwbclient0 libwebkit2gtk-4.0-37',
#  '  libwebrtc-audio-processing1 libwhoopsie-preferences0 libwhoopsie0 libwoff1',
#  '  libwxbase3.0-0v5 libwxgtk3.0-gtk3-0v5 libxatracker2 libxcb-res0 libxcb-xv0',
#  '  libxfont2 libxkbfile1 libxklavier16 libxtst6 libxvmc1 libyelp0',
#  '  mesa-vulkan-drivers mobile-broadband-provider-info modemmanager mousetweaks',
#  '  mutter mutter-common netbase network-manager network-manager-gnome',
#  '  network-manager-pptp p11-kit p11-kit-modules pci.ids pinentry-gnome3 ppp',
#  '  pptp-linux pulseaudio pulseaudio-module-bluetooth pulseaudio-utils',
#  '  python3-apport python3-aptdaemon python3-aptdaemon.gtk3widgets',
#  '  python3-blinker python3-cairo python3-cffi-backend python3-cryptography',
#  '  python3-cups python3-cupshelpers python3-defer python3-distro',
#  '  python3-entrypoints python3-httplib2 python3-ibus-1.0 python3-jwt',
#  '  python3-keyring python3-launchpadlib python3-lazr.restfulclient',
#  '  python3-lazr.uri python3-ldb python3-macaroonbakery python3-nacl',
#  '  python3-oauthlib python3-problem-report python3-protobuf python3-pymacaroons',
#  '  python3-rfc3339 python3-secretstorage python3-simplejson python3-systemd',
#  '  python3-talloc python3-tz python3-wadllib rtkit rygel samba-libs sane-utils',
#  '  session-migration sgml-base sgml-data switcheroo-control',
#  '  system-config-printer system-config-printer-common',
#  '  system-config-printer-udev ubuntu-docs ubuntu-session ubuntu-wallpapers',
#  '  ubuntu-wallpapers-focal udev update-inetd upower usb-modeswitch',
#  '  usb-modeswitch-data usb.ids usbmuxd wamerican whoopsie-preferences',
#  '  wireless-regdb wpasupplicant x11-xkb-utils x11-xserver-utils xdg-dbus-proxy',
#  '  xfonts-base xfonts-encodings xfonts-utils xml-core xserver-common',
#  '  xserver-xephyr xserver-xorg xserver-xorg-core xserver-xorg-input-all',
#  '  xserver-xorg-input-libinput xserver-xorg-input-wacom xserver-xorg-legacy',
#  '  xserver-xorg-video-all xserver-xorg-video-amdgpu xserver-xorg-video-ati',
#  '  xserver-xorg-video-fbdev xserver-xorg-video-intel xserver-xorg-video-nouveau',
#  '  xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa',
#  '  xserver-xorg-video-vmware xwayland yaru-theme-gnome-shell yelp yelp-xsl',
#  '  zenity zenity-common',
#  'Suggested packages:',
#  '  apport-gtk | apport-kde aspell-doc spellutils avahi-autoipd',
#  '  colord-sensor-argyll docbook docbook-dsssl docbook-xsl docbook-defguide',
#  '  erlang-manpages erlang-doc xsltproc fop evolution gnome-orca gnome-software',
#  '  | gnome-packagekit gnome-user-share realmd libcanberra-gtk-module usbguard',
#  '  chrome-gnome-shell gir1.2-telepathyglib-0.12 gnome-themes-standard-data',
#  '  gnome-backgrounds gir1.2-telepathylogger-0.2 gvfs hunspell',
#  '  openoffice.org-hunspell | openoffice.org-core ibus-clutter ibus-doc',
#  '  firewalld nftables apache2 | lighttpd | httpd indicator-application',
#  '  libdv-bin oss-compat libenchant-2-voikko libusbmuxd-tools mmdb-bin',
#  '  avahi-autoipd | zeroconf hplip lksctp-tools snapd snmp-mibs-downloader',
#  '  libvisual-0.4-plugins gstreamer1.0-libav xdg-user-dirs libteam-utils',
#  '  isc-dhcp-client network-manager-openconnect-gnome',
#  '  network-manager-openvpn-gnome network-manager-vpnc-gnome',
#  '  network-manager-pptp-gnome pinentry-doc pavumeter pavucontrol paman paprefs',
#  '  ubuntu-sounds python-blinker-doc python-cryptography-doc',
#  '  python3-cryptography-vectors python3-crypto libkf5wallet-bin',
#  '  python3-keyrings.alt python3-testresources python-nacl-doc',
#  '  python-secretstorage-doc gstreamer1.0-plugins-ugly rygel-playbin',
#  '  rygel-preferences rygel-ruih rygel-tracker tumbler unpaper sgml-base-doc',
#  '  perlsgml w3-recs opensp libxml2-utils gnome-software python3-smbc',
#  '  ubuntu-wallpapers-karmic ubuntu-wallpapers-lucid ubuntu-wallpapers-maverick',
#  '  ubuntu-wallpapers-natty ubuntu-wallpapers-oneiric ubuntu-wallpapers-precise',
#  '  ubuntu-wallpapers-quantal ubuntu-wallpapers-raring ubuntu-wallpapers-saucy',
#  '  ubuntu-wallpapers-trusty ubuntu-wallpapers-utopic ubuntu-wallpapers-vivid',
#  '  ubuntu-wallpapers-wily ubuntu-wallpapers-xenial ubuntu-wallpapers-yakkety',
#  '  ubuntu-wallpapers-zesty ubuntu-wallpapers-artful ubuntu-wallpapers-bionic',
#  '  ubuntu-wallpapers-cosmic ubuntu-wallpapers-disco ubuntu-wallpapers-eoan',
#  '  comgt wvdial wpagui libengine-pkcs11-openssl nickle cairo-5c xorg-docs-core',
#  '  debhelper xfonts-100dpi | xfonts-75dpi xfonts-scalable xinput',
#  '  firmware-amd-graphics xserver-xorg-video-r128 xserver-xorg-video-mach64',
#  '  firmware-misc-nonfree',
#  'The following NEW packages will be installed:',
#  '  accountsservice acl apg apport apport-symptoms aptdaemon aptdaemon-data',
#  '  aspell aspell-en at-spi2-core avahi-daemon avahi-utils bind9-host bind9-libs',
#  '  bluez bolt bubblewrap cheese-common colord colord-data cracklib-runtime crda',
#  '  cups-pk-helper dbus-x11 dconf-cli desktop-file-utils dictionaries-common',
#  '  dns-root-data dnsmasq-base docbook-xml emacsen-common enchant-2 erlang',
#  '  erlang-asn1 erlang-base erlang-common-test erlang-crypto erlang-debugger',
#  '  erlang-dev erlang-dialyzer erlang-diameter erlang-edoc erlang-eldap',
#  '  erlang-erl-docgen erlang-et erlang-eunit erlang-examples erlang-ftp',
#  '  erlang-inets erlang-jinterface erlang-megaco erlang-mnesia erlang-mode',
#  '  erlang-observer erlang-odbc erlang-os-mon erlang-parsetools',
#  '  erlang-public-key erlang-reltool erlang-runtime-tools erlang-snmp erlang-src',
#  '  erlang-ssh erlang-ssl erlang-syntax-tools erlang-tftp erlang-tools erlang-wx',
#  '  erlang-xmerl evolution-data-server evolution-data-server-common fprintd gcr',
#  '  gdm3 geoclue-2.0 gettext-base gir1.2-accountsservice-1.0 gir1.2-atk-1.0',
#  '  gir1.2-atspi-2.0 gir1.2-freedesktop gir1.2-gck-1 gir1.2-gcr-3',
#  '  gir1.2-gdesktopenums-3.0 gir1.2-gdkpixbuf-2.0 gir1.2-gdm-1.0',
#  '  gir1.2-geoclue-2.0 gir1.2-gnomebluetooth-1.0 gir1.2-gnomedesktop-3.0',
#  '  gir1.2-graphene-1.0 gir1.2-gtk-3.0 gir1.2-gweather-3.0 gir1.2-ibus-1.0',
#  '  gir1.2-json-1.0 gir1.2-mutter-6 gir1.2-nm-1.0 gir1.2-nma-1.0',
#  '  gir1.2-notify-0.7 gir1.2-pango-1.0 gir1.2-polkit-1.0 gir1.2-rsvg-2.0',
#  '  gir1.2-secret-1 gir1.2-soup-2.4 gir1.2-upowerglib-1.0 gir1.2-vte-2.91 gjs',
#  '  gkbd-capplet gnome-control-center gnome-control-center-data',
#  '  gnome-control-center-faces gnome-desktop3-data gnome-keyring',
#  '  gnome-keyring-pkcs11 gnome-menus gnome-online-accounts gnome-session-bin',
#  '  gnome-session-common gnome-settings-daemon gnome-settings-daemon-common',
#  '  gnome-shell gnome-shell-common gnome-startup-applications gnome-user-docs',
#  '  gstreamer1.0-clutter-3.0 gstreamer1.0-gl gstreamer1.0-plugins-base',
#  '  gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x',
#  '  hunspell-en-us ibus ibus-data ibus-gtk ibus-gtk3 iio-sensor-proxy im-config',
#  '  ippusbxd iptables iw javascript-common keyboard-configuration',
#  '  language-selector-common language-selector-gnome libaa1 libaccountsservice0',
#  '  libappindicator3-1 libasound2-plugins libaspell15 libavahi-core7',
#  '  libavahi-glib1 libbluetooth3 libcamel-1.2-62 libcanberra-gtk3-0',
#  '  libcanberra-gtk3-module libcanberra-pulse libcdparanoia0 libcheese-gtk25',
#  '  libcheese8 libclutter-1.0-0 libclutter-1.0-common libclutter-gst-3.0-0',
#  '  libclutter-gtk-1.0-0 libcogl-common libcogl-pango20 libcogl-path20 libcogl20',
#  '  libcolord-gtk1 libcolorhug2 libcrack2 libdaemon0 libdbusmenu-glib4',
#  '  libdbusmenu-gtk3-4 libdv4 libebackend-1.2-10 libebook-1.2-20',
#  '  libebook-contacts-1.2-3 libecal-2.0-1 libedata-book-1.2-26',
#  '  libedata-cal-2.0-1 libedataserver-1.2-24 libedataserverui-1.2-2',
#  '  libenchant-2-2 libfontenc1 libfprint-2-2 libgail-common libgail18 libgck-1-0',
#  '  libgcr-base-3-1 libgcr-ui-3-1 libgdata-common libgdata22 libgdm1',
#  '  libgee-0.8-2 libgeoclue-2-0 libgeocode-glib0 libgjs0g libgnome-autoar-0-0',
#  '  libgnome-bluetooth13 libgnome-desktop-3-19 libgnomekbd-common libgnomekbd8',
#  '  libgoa-1.0-0b libgoa-1.0-common libgoa-backend-1.0-1 libgraphene-1.0-0',
#  '  libgsound0 libgssdp-1.2-0 libgstreamer-gl1.0-0',
#  '  libgstreamer-plugins-good1.0-0 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common',
#  '  libgtop-2.0-11 libgtop2-common libgupnp-1.2-0 libgupnp-av-1.0-2',
#  '  libgupnp-dlna-2.0-3 libgusb2 libgweather-3-16 libgweather-common',
#  '  libharfbuzz-icu0 libhunspell-1.7-0 libhyphen0 libibus-1.0-5 libical3',
#  '  libidn11 libieee1284-3 libimobiledevice6 libip6tc2 libjansson4',
#  '  libjavascriptcoregtk-4.0-18 libjs-jquery libjs-jquery-metadata',
#  '  libjs-jquery-tablesorter libldb2 liblocale-gettext-perl libmaxminddb0',
#  '  libmbim-glib4 libmbim-proxy libmediaart-2.0-0 libmm-glib0 libmozjs-68-0',
#  '  libmutter-6-0 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0',
#  '  libnftnl11 libnl-genl-3-200 libnm0 libnma0 libnotify4 libnss-mdns',
#  '  libpam-fprintd libpam-gnome-keyring libpangoxft-1.0-0 libpcap0.8 libpci3',
#  '  libphonenumber7 libplist3 libpulse-mainloop-glib0 libpulsedsp',
#  '  libpwquality-common libpwquality1 libqmi-glib5 libqmi-proxy',
#  '  librygel-core-2.6-2 librygel-db-2.6-2 librygel-renderer-2.6-2',
#  '  librygel-server-2.6-2 libsane libsane-common libsbc1 libsctp1 libsecret-1-0',
#  '  libsecret-common libshout3 libsmbclient libsnapd-glib1 libsnmp-base',
#  '  libsnmp35 libspeexdsp1 libstartup-notification0 libtag1v5 libtag1v5-vanilla',
#  '  libtalloc2 libteamdctl0 libtevent0 libtext-iconv-perl libudisks2-0',
#  '  libupower-glib3 libusbmuxd6 libv4l-0 libv4lconvert0 libvisual-0.4-0',
#  '  libvte-2.91-0 libvte-2.91-common libwbclient0 libwebkit2gtk-4.0-37',
#  '  libwebrtc-audio-processing1 libwhoopsie-preferences0 libwhoopsie0 libwoff1',
#  '  libwxbase3.0-0v5 libwxgtk3.0-gtk3-0v5 libxatracker2 libxcb-res0 libxcb-xv0',
#  '  libxfont2 libxkbfile1 libxklavier16 libxtst6 libxvmc1 libyelp0',
#  '  mesa-vulkan-drivers mobile-broadband-provider-info modemmanager mousetweaks',
#  '  mutter mutter-common netbase network-manager network-manager-gnome',
#  '  network-manager-pptp p11-kit p11-kit-modules pci.ids pinentry-gnome3 ppp',
#  '  pptp-linux pulseaudio pulseaudio-module-bluetooth pulseaudio-utils',
#  '  python3-apport python3-aptdaemon python3-aptdaemon.gtk3widgets',
#  '  python3-blinker python3-cairo python3-cffi-backend python3-cryptography',
#  '  python3-cups python3-cupshelpers python3-defer python3-distro',
#  '  python3-entrypoints python3-httplib2 python3-ibus-1.0 python3-jwt',
#  '  python3-keyring python3-launchpadlib python3-lazr.restfulclient',
#  '  python3-lazr.uri python3-ldb python3-macaroonbakery python3-nacl',
#  '  python3-oauthlib python3-problem-report python3-protobuf python3-pymacaroons',
#  '  python3-rfc3339 python3-secretstorage python3-simplejson python3-systemd',
#  '  python3-talloc python3-tz python3-wadllib rtkit rygel samba-libs sane-utils',
#  '  session-migration sgml-base sgml-data switcheroo-control',
#  '  system-config-printer system-config-printer-common',
#  '  system-config-printer-udev ubuntu-docs ubuntu-session ubuntu-wallpapers',
#  '  ubuntu-wallpapers-focal udev update-inetd upower usb-modeswitch',
#  '  usb-modeswitch-data usb.ids usbmuxd wamerican whoopsie-preferences',
#  '  wireless-regdb wpasupplicant x11-xkb-utils x11-xserver-utils xdg-dbus-proxy',
#  '  xfonts-base xfonts-encodings xfonts-utils xml-core xserver-common',
#  '  xserver-xephyr xserver-xorg xserver-xorg-core xserver-xorg-input-all',
#  '  xserver-xorg-input-libinput xserver-xorg-input-wacom xserver-xorg-legacy',
#  '  xserver-xorg-video-all xserver-xorg-video-amdgpu xserver-xorg-video-ati',
#  '  xserver-xorg-video-fbdev xserver-xorg-video-intel xserver-xorg-video-nouveau',
#  '  xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa',
#  '  xserver-xorg-video-vmware xwayland yaru-theme-gnome-shell yelp yelp-xsl',
#  '  zenity zenity-common',
#  'The following packages will be upgraded:',
#  '  libudev1',
#  '1 upgraded, 422 newly installed, 0 to remove and 23 not upgraded.',
#  'Need to get 164 MB of archives.',
#  'After this operation, 609 MB of additional disk space will be used.',
#  '\x1b',
#  '0% [Working]\x1b',
#  '            ',
#  'Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 liblocale-gettext-perl amd64 1.07-4 [17.1 kB]',
#  '\x1b',
#  '0% [1 liblocale-gettext-perl 0 B/17.1 kB 0%]\x1b\x1b',
#  '                                            ',
#  '0% [Working]\x1b',
#  '            ',
#  'Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 keyboard-configuration all 1.194ubuntu3 [190 kB]',
#  '\x1b',
#  '0% [2 keyboard-configuration 0 B/190 kB 0%]\x1b\x1b',
#  '                                           ',
#  '0% [Working]\x1b',
#  '            ',
#  'Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaccountsservice0 amd64 0.6.55-0ubuntu12~20.04.5 [72.6 kB]',
#  '\x1b',
#  '0% [3 libaccountsservice0 0 B/72.6 kB 0%]\x1b\x1b',
#  '                                         ',
#  '0% [Working]\x1b',
#  '            ',
#  'Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 accountsservice amd64 0.6.55-0ubuntu12~20.04.5 [61.0 kB]',
#  '\x1b',
#  '0% [4 accountsservice 514 B/61.0 kB 1%]\x1b\x1b',
#  '                                       ',
#  '0% [Working]\x1b',
#  '            ',
#  'Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 language-selector-common all 0.204.2 [224 kB]',
#  '\x1b',
#  '0% [5 language-selector-common 0 B/224 kB 0%]\x1b\x1b',
#  '                                             ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsane-common all 1.0.29-0ubuntu5.2 [277 kB]',
#  '\x1b',
#  '1% [6 libsane-common 0 B/277 kB 0%]\x1b\x1b',
#  '                                   ',
#  '1% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtalloc2 amd64 2.3.3-0ubuntu0.20.04.1 [29.6 kB]',
#  '\x1b',
#  '1% [7 libtalloc2 9,131 B/29.6 kB 31%]\x1b\x1b',
#  '                                     ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libtevent0 amd64 0.11.0-0ubuntu0.20.04.1 [36.2 kB]',
#  '\x1b',
#  '1% [8 libtevent0 0 B/36.2 kB 0%]\x1b\x1b',
#  '                                ',
#  '1% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwbclient0 amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [210 kB]',
#  '\x1b',
#  '1% [9 libwbclient0 3,623 B/210 kB 2%]\x1b\x1b',
#  '                                     ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnapd-glib1 amd64 1.58-0ubuntu0.20.04.0 [90.1 kB]',
#  '\x1b',
#  '1% [10 libsnapd-glib1 0 B/90.1 kB 0%]\x1b\x1b',
#  '                                     ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libspeexdsp1 amd64 1.2~rc1.2-1.1ubuntu1.20.04.1 [40.4 kB]',
#  '\x1b',
#  '1% [11 libspeexdsp1 0 B/40.4 kB 0%]\x1b\x1b',
#  '                                   ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev1 amd64 245.4-4ubuntu3.21 [75.9 kB]',
#  '\x1b',
#  '1% [12 libudev1 0 B/75.9 kB 0%]\x1b\x1b',
#  '                               ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu3 [263 kB]',
#  '\x1b',
#  '1% [13 libwebrtc-audio-processing1 0 B/263 kB 0%]\x1b\x1b',
#  '                                                 ',
#  '1% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]',
#  '\x1b',
#  '1% [14 libxtst6 4,096 B/12.8 kB 32%]\x1b\x1b',
#  '                                    ',
#  '1% [Working]\x1b',
#  '            ',
#  'Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libasound2-plugins amd64 1.2.2-1ubuntu1 [66.0 kB]',
#  '\x1b',
#  '1% [15 libasound2-plugins 0 B/66.0 kB 0%]\x1b\x1b',
#  '                                         ',
#  '2% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulsedsp amd64 1:13.99.1-1ubuntu3.13 [21.7 kB]',
#  '\x1b',
#  '2% [16 libpulsedsp 1,955 B/21.7 kB 9%]\x1b\x1b',
#  '                                      ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 pulseaudio-utils amd64 1:13.99.1-1ubuntu3.13 [55.0 kB]',
#  '\x1b',
#  '2% [17 pulseaudio-utils 0 B/55.0 kB 0%]\x1b\x1b',
#  '                                       ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 pulseaudio amd64 1:13.99.1-1ubuntu3.13 [814 kB]',
#  '\x1b',
#  '2% [18 pulseaudio 0 B/814 kB 0%]\x1b\x1b',
#  '                                ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 sgml-base all 1.29.1 [12.4 kB]',
#  '\x1b',
#  '2% [19 sgml-base 0 B/12.4 kB 0%]\x1b\x1b',
#  '                                ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libjansson4 amd64 2.12-1build1 [28.9 kB]',
#  '\x1b',
#  '2% [20 libjansson4 0 B/28.9 kB 0%]\x1b\x1b',
#  '                                  ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libldb2 amd64 2:2.4.4-0ubuntu0.20.04.2 [143 kB]',
#  '\x1b',
#  '2% [21 libldb2 0 B/143 kB 0%]\x1b\x1b',
#  '                             ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-ldb amd64 2:2.4.4-0ubuntu0.20.04.2 [38.2 kB]',
#  '\x1b',
#  '2% [22 python3-ldb 0 B/38.2 kB 0%]\x1b\x1b',
#  '                                  ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-talloc amd64 2.3.3-0ubuntu0.20.04.1 [12.2 kB]',
#  '\x1b',
#  '2% [23 python3-talloc 0 B/12.2 kB 0%]\x1b\x1b',
#  '                                     ',
#  '2% [Working]\x1b',
#  '            ',
#  'Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 samba-libs amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [5,715 kB]',
#  '\x1b',
#  '2% [24 samba-libs 0 B/5,715 kB 0%]\x1b\x1b',
#  '3% [24 samba-libs 1,302 kB/5,715 kB 23%]\x1b\x1b',
#  '                                        ',
#  '5% [Working]\x1b',
#  '            ',
#  'Get:25 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsmbclient amd64 2:4.15.13+dfsg-0ubuntu0.20.04.2 [59.4 kB]',
#  '\x1b',
#  '5% [25 libsmbclient 0 B/59.4 kB 0%]\x1b\x1b',
#  '                                   ',
#  '5% [Working]\x1b',
#  '            ',
#  'Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libnewt0.52 amd64 0.52.21-4ubuntu2 [41.1 kB]',
#  '\x1b',
#  '5% [26 libnewt0.52 41.1 kB/41.1 kB 100%]\x1b\x1b',
#  '                                        ',
#  '5% [Working]\x1b',
#  '            ',
#  'Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libtext-iconv-perl amd64 1.7-7 [13.8 kB]',
#  '\x1b',
#  '5% [27 libtext-iconv-perl 3,483 B/13.8 kB 25%]\x1b\x1b',
#  '                                              ',
#  '5% [Working]\x1b',
#  '            ',
#  'Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 netbase all 6.1 [13.1 kB]',
#  '\x1b',
#  '5% [28 netbase 13.1 kB/13.1 kB 100%]\x1b\x1b',
#  '                                    ',
#  '6% [Working]\x1b',
#  '            ',
#  'Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-cffi-backend amd64 1.14.0-1build1 [68.7 kB]',
#  '\x1b',
#  '6% [29 python3-cffi-backend 0 B/68.7 kB 0%]\x1b\x1b',
#  '                                           ',
#  '6% [Working]\x1b',
#  '            ',
#  'Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-nacl amd64 1.3.0-5 [49.0 kB]',
#  '\x1b',
#  '6% [30 python3-nacl 0 B/49.0 kB 0%]\x1b\x1b',
#  '                                   ',
#  '6% [Working]\x1b',
#  '            ',
#  'Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pymacaroons all 0.13.0-3 [13.2 kB]',
#  '\x1b',
#  '6% [31 python3-pymacaroons 0 B/13.2 kB 0%]\x1b\x1b',
#  '                                          ',
#  '6% [Working]\x1b',
#  '            ',
#  'Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 udev amd64 245.4-4ubuntu3.21 [1,366 kB]',
#  '\x1b',
#  '6% [32 udev 4,096 B/1,366 kB 0%]\x1b\x1b',
#  '                                ',
#  '6% [Working]\x1b',
#  '            ',
#  'Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmaxminddb0 amd64 1.4.2-0ubuntu1.20.04.1 [26.2 kB]',
#  '\x1b',
#  '6% [33 libmaxminddb0 0 B/26.2 kB 0%]\x1b\x1b',
#  '                                    ',
#  '7% [Working]\x1b',
#  '            ',
#  'Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-libs amd64 1:9.16.1-0ubuntu2.14 [1,109 kB]',
#  '\x1b',
#  '7% [34 bind9-libs 0 B/1,109 kB 0%]\x1b\x1b',
#  '7% [34 bind9-libs 697 kB/1,109 kB 63%]\x1b\x1b',
#  '                                      ',
#  '7% [Working]\x1b',
#  '            ',
#  'Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bind9-host amd64 1:9.16.1-0ubuntu2.14 [43.0 kB]',
#  '\x1b',
#  '7% [35 bind9-host 0 B/43.0 kB 0%]\x1b\x1b',
#  '                                 ',
#  '7% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext-base amd64 0.19.8.1-10build1 [50.2 kB]',
#  '\x1b',
#  '7% [36 gettext-base 11.4 kB/50.2 kB 23%]\x1b\x1b',
#  '                                        ',
#  '7% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 libip6tc2 amd64 1.8.4-3ubuntu2 [19.2 kB]',
#  '\x1b',
#  '7% [37 libip6tc2 15.8 kB/19.2 kB 82%]\x1b\x1b',
#  '                                     ',
#  '7% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libnfnetlink0 amd64 1.0.1-3build1 [13.8 kB]',
#  '\x1b',
#  '7% [38 libnfnetlink0 13.8 kB/13.8 kB 100%]\x1b\x1b',
#  '                                          ',
#  '7% [Working]\x1b',
#  '            ',
#  'Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libnetfilter-conntrack3 amd64 1.0.7-2 [41.4 kB]',
#  '\x1b',
#  '7% [39 libnetfilter-conntrack3 559 B/41.4 kB 1%]\x1b\x1b',
#  '                                                ',
#  '7% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libnftnl11 amd64 1.1.5-1 [57.8 kB]',
#  '\x1b',
#  '7% [40 libnftnl11 5,322 B/57.8 kB 9%]\x1b\x1b',
#  '                                     ',
#  '8% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 iptables amd64 1.8.4-3ubuntu2 [390 kB]',
#  '\x1b',
#  '8% [41 iptables 12.0 kB/390 kB 3%]\x1b\x1b',
#  '                                  ',
#  '8% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libpcap0.8 amd64 1.9.1-3 [128 kB]',
#  '\x1b',
#  '8% [42 libpcap0.8 28.3 kB/128 kB 22%]\x1b\x1b',
#  '                                     ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 pci.ids all 0.0~2020.03.20-1 [217 kB]',
#  '\x1b',
#  '8% [43 pci.ids 0 B/217 kB 0%]\x1b\x1b',
#  '                             ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpci3 amd64 1:3.6.4-1ubuntu0.20.04.1 [26.9 kB]',
#  '\x1b',
#  '8% [44 libpci3 0 B/26.9 kB 0%]\x1b\x1b',
#  '                              ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 usb.ids all 2020.03.19-1 [176 kB]',
#  '\x1b',
#  '8% [45 usb.ids 0 B/176 kB 0%]\x1b\x1b',
#  '                             ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:46 http://archive.ubuntu.com/ubuntu focal/main amd64 acl amd64 2.2.53-6 [37.8 kB]',
#  '\x1b',
#  '8% [46 acl 0 B/37.8 kB 0%]\x1b\x1b',
#  '                          ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 apg amd64 2.2.3.dfsg.1-5 [50.6 kB]',
#  '\x1b',
#  '8% [47 apg 1,106 B/50.6 kB 2%]\x1b\x1b',
#  '                              ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:48 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-httplib2 all 0.14.0-1ubuntu1 [28.9 kB]',
#  '\x1b',
#  '8% [48 python3-httplib2 893 B/28.9 kB 3%]\x1b\x1b',
#  '                                         ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:49 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-problem-report all 2.20.11-0ubuntu27.26 [11.1 kB]',
#  '\x1b',
#  '8% [49 python3-problem-report 0 B/11.1 kB 0%]\x1b\x1b',
#  '                                             ',
#  '8% [Working]\x1b',
#  '            ',
#  'Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-entrypoints all 0.3-2ubuntu1 [5,740 B]',
#  '\x1b',
#  '8% [50 python3-entrypoints 0 B/5,740 B 0%]\x1b\x1b',
#  '                                          ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:51 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-cryptography amd64 2.8-3ubuntu0.1 [211 kB]',
#  '\x1b',
#  '9% [51 python3-cryptography 0 B/211 kB 0%]\x1b\x1b',
#  '                                          ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-secretstorage all 2.3.1-2ubuntu1 [12.4 kB]',
#  '\x1b',
#  '9% [52 python3-secretstorage 0 B/12.4 kB 0%]\x1b\x1b',
#  '                                            ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-keyring all 18.0.1-2ubuntu1 [28.7 kB]',
#  '\x1b',
#  '9% [53 python3-keyring 0 B/28.7 kB 0%]\x1b\x1b',
#  '                                      ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:54 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-lazr.uri all 1.0.3-4build1 [13.9 kB]',
#  '\x1b',
#  '9% [54 python3-lazr.uri 0 B/13.9 kB 0%]\x1b\x1b',
#  '                                       ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-simplejson amd64 3.16.0-2ubuntu2 [50.8 kB]',
#  '\x1b',
#  '9% [55 python3-simplejson 0 B/50.8 kB 0%]\x1b\x1b',
#  '                                         ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:56 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-wadllib all 1.3.3-3build1 [45.4 kB]',
#  '\x1b',
#  '9% [56 python3-wadllib 0 B/45.4 kB 0%]\x1b\x1b',
#  '                                      ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:57 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-distro all 1.4.0-1 [14.6 kB]',
#  '\x1b',
#  '9% [57 python3-distro 2,535 B/14.6 kB 17%]\x1b\x1b',
#  '                                          ',
#  '9% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-blinker all 1.4+dfsg1-0.3ubuntu1 [13.2 kB]',
#  '\x1b',
#  '9% [58 python3-blinker 1,734 B/13.2 kB 13%]\x1b\x1b',
#  '                                           ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:59 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-jwt all 1.7.1-2ubuntu2.1 [18.0 kB]',
#  '\x1b',
#  '9% [59 python3-jwt 0 B/18.0 kB 0%]\x1b\x1b',
#  '                                  ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-oauthlib all 3.1.0-1ubuntu2 [84.8 kB]',
#  '\x1b',
#  '9% [60 python3-oauthlib 0 B/84.8 kB 0%]\x1b\x1b',
#  '                                       ',
#  '9% [Waiting for headers]\x1b',
#  '                        ',
#  'Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-lazr.restfulclient all 0.14.2-2build1 [50.7 kB]',
#  '\x1b',
#  '9% [61 python3-lazr.restfulclient 210 B/50.7 kB 0%]\x1b\x1b',
#  '                                                   ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:62 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-launchpadlib all 1.10.13-1 [50.0 kB]',
#  '\x1b',
#  '9% [62 python3-launchpadlib 0 B/50.0 kB 0%]\x1b\x1b',
#  '                                           ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:63 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-apport all 2.20.11-0ubuntu27.26 [87.0 kB]',
#  '\x1b',
#  '9% [63 python3-apport 0 B/87.0 kB 0%]\x1b\x1b',
#  '                                     ',
#  '9% [Working]\x1b',
#  '            ',
#  'Get:64 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apport all 2.20.11-0ubuntu27.26 [129 kB]',
#  '\x1b',
#  '9% [64 apport 0 B/129 kB 0%]\x1b\x1b',
#  '                            ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:65 http://archive.ubuntu.com/ubuntu focal/main amd64 apport-symptoms all 0.23 [13.5 kB]',
#  '\x1b',
#  '10% [65 apport-symptoms 3,151 B/13.5 kB 23%]\x1b\x1b',
#  '                                            ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:66 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libaspell15 amd64 0.60.8-1ubuntu0.1 [328 kB]',
#  '\x1b',
#  '10% [66 libaspell15 0 B/328 kB 0%]\x1b\x1b',
#  '                                  ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 emacsen-common all 3.0.4 [14.9 kB]',
#  '\x1b',
#  '10% [67 emacsen-common 0 B/14.9 kB 0%]\x1b\x1b',
#  '                                      ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 dictionaries-common all 1.28.1 [178 kB]',
#  '\x1b',
#  '10% [68 dictionaries-common 0 B/178 kB 0%]\x1b\x1b',
#  '                                          ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:69 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 aspell amd64 0.60.8-1ubuntu0.1 [88.4 kB]',
#  '\x1b',
#  '10% [69 aspell 0 B/88.4 kB 0%]\x1b\x1b',
#  '                              ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 aspell-en all 2018.04.16-0-1 [299 kB]',
#  '\x1b',
#  '10% [70 aspell-en 1,220 B/299 kB 0%]\x1b\x1b',
#  '                                    ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 at-spi2-core amd64 2.36.0-2 [48.7 kB]',
#  '\x1b',
#  '10% [71 at-spi2-core 0 B/48.7 kB 0%]\x1b\x1b',
#  '                                    ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:72 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libavahi-core7 amd64 0.7-4ubuntu7.1 [82.0 kB]',
#  '\x1b',
#  '10% [72 libavahi-core7 1,009 B/82.0 kB 1%]\x1b\x1b',
#  '                                          ',
#  '10% [Working]\x1b',
#  '             ',
#  'Get:73 http://archive.ubuntu.com/ubuntu focal/main amd64 libdaemon0 amd64 0.14-7 [13.9 kB]',
#  '\x1b',
#  '10% [73 libdaemon0 4,620 B/13.9 kB 33%]\x1b\x1b',
#  '                                       ',
#  '11% [Working]\x1b',
#  '             ',
#  'Get:74 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 avahi-daemon amd64 0.7-4ubuntu7.1 [61.0 kB]',
#  '\x1b',
#  '11% [74 avahi-daemon 0 B/61.0 kB 0%]\x1b\x1b',
#  '                                    ',
#  '11% [Working]\x1b',
#  '             ',
#  'Get:75 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 avahi-utils amd64 0.7-4ubuntu7.1 [24.7 kB]',
#  '\x1b',
#  '11% [75 avahi-utils 914 B/24.7 kB 4%]\x1b\x1b',
#  '                                     ',
#  '11% [Working]\x1b',
#  '             ',
#  'Get:76 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bluez amd64 5.53-0ubuntu3.6 [982 kB]',
#  '\x1b',
#  '11% [76 bluez 0 B/982 kB 0%]\x1b\x1b',
#  '                            ',
#  '11% [Working]\x1b',
#  '             ',
#  'Get:77 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 bolt amd64 0.9.1-2~ubuntu20.04.2 [143 kB]',
#  '\x1b',
#  '11% [77 bolt 0 B/143 kB 0%]\x1b\x1b',
#  '11% [Connecting to archive.ubuntu.com (91.189.91.39)]\x1b',
#  '                                                     ',
#  'Get:78 http://archive.ubuntu.com/ubuntu focal/main amd64 bubblewrap amd64 0.4.0-1ubuntu4 [35.4 kB]',
#  '\x1b',
#  '11% [78 bubblewrap 0 B/35.4 kB 0%]                               2,561 kB/s 57s\x1b\x1b',
#  '11% [Working]                                                    2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:79 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 cheese-common all 3.34.0-1ubuntu1 [390 kB]',
#  '\x1b',
#  '11% [79 cheese-common 2,533 B/390 kB 1%]                         2,561 kB/s 57s\x1b\x1b',
#  '12% [Waiting for headers]                                        2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:80 http://archive.ubuntu.com/ubuntu focal/main amd64 libgusb2 amd64 0.3.4-0.1 [22.1 kB]',
#  '\x1b',
#  '12% [80 libgusb2 6,292 B/22.1 kB 28%]                            2,561 kB/s 57s\x1b\x1b',
#  '12% [Waiting for headers]                                        2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:81 http://archive.ubuntu.com/ubuntu focal/main amd64 libcolorhug2 amd64 1.4.4-2 [38.4 kB]',
#  '\x1b',
#  '12% [81 libcolorhug2 811 B/38.4 kB 2%]                           2,561 kB/s 57s\x1b\x1b',
#  '12% [Working]                                                    2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:82 http://archive.ubuntu.com/ubuntu focal/main amd64 libieee1284-3 amd64 0.2.11-13build1 [21.0 kB]',
#  '\x1b',
#  '12% [82 libieee1284-3 134 B/21.0 kB 1%]                          2,561 kB/s 57s\x1b\x1b',
#  '12% [Working]                                                    2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:83 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnmp-base all 5.8+dfsg-2ubuntu2.7 [206 kB]',
#  '\x1b',
#  '12% [83 libsnmp-base 14.1 kB/206 kB 7%]                          2,561 kB/s 57s\x1b\x1b',
#  '12% [Waiting for headers]                                        2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:84 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsnmp35 amd64 5.8+dfsg-2ubuntu2.7 [978 kB]',
#  '\x1b',
#  '12% [84 libsnmp35 680 B/978 kB 0%]                               2,561 kB/s 57s\x1b',
#  '                                                                               ',
#  'Get:85 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsane amd64 1.0.29-0ubuntu5.2 [2,405 kB]',
#  '\x1b',
#  '12% [85 libsane 54.0 kB/2,405 kB 2%]                             2,561 kB/s 57s\x1b\x1b',
#  '14% [Working]                                                    2,561 kB/s 56s\x1b',
#  '                                                                               ',
#  'Get:86 http://archive.ubuntu.com/ubuntu focal/main amd64 colord-data all 1.4.4-2 [1,093 kB]',
#  '\x1b',
#  '14% [86 colord-data 0 B/1,093 kB 0%]                             2,561 kB/s 56s\x1b\x1b',
#  '14% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:87 http://archive.ubuntu.com/ubuntu focal/main amd64 colord amd64 1.4.4-2 [192 kB]',
#  '\x1b',
#  '14% [87 colord 0 B/192 kB 0%]                                    2,561 kB/s 55s\x1b\x1b',
#  '14% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:88 http://archive.ubuntu.com/ubuntu focal/main amd64 libcrack2 amd64 2.9.6-3.2 [28.3 kB]',
#  '\x1b',
#  '14% [88 libcrack2 0 B/28.3 kB 0%]                                2,561 kB/s 55s\x1b\x1b',
#  '14% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:89 http://archive.ubuntu.com/ubuntu focal/main amd64 cracklib-runtime amd64 2.9.6-3.2 [140 kB]',
#  '\x1b',
#  '14% [89 cracklib-runtime 13.8 kB/140 kB 10%]                     2,561 kB/s 55s\x1b\x1b',
#  '15% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:90 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnl-genl-3-200 amd64 3.4.0-1ubuntu0.1 [11.2 kB]',
#  '\x1b',
#  '15% [90 libnl-genl-3-200 5,351 B/11.2 kB 48%]                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:91 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 wireless-regdb all 2022.06.06-0ubuntu1~20.04.1 [9,872 B]',
#  '\x1b',
#  '15% [91 wireless-regdb 5,115 B/9,872 B 52%]                      2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:92 http://archive.ubuntu.com/ubuntu focal/main amd64 iw amd64 5.4-1 [94.0 kB]',
#  '\x1b',
#  '15% [92 iw 593 B/94.0 kB 1%]                                     2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:93 http://archive.ubuntu.com/ubuntu focal/main amd64 crda amd64 3.18-1build1 [63.5 kB]',
#  '\x1b',
#  '15% [93 crda 2,088 B/63.5 kB 3%]                                 2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:94 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dbus-x11 amd64 1.12.16-2ubuntu2.3 [22.6 kB]',
#  '\x1b',
#  '15% [94 dbus-x11 283 B/22.6 kB 1%]                               2,561 kB/s 55s\x1b\x1b',
#  '15% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:95 http://archive.ubuntu.com/ubuntu focal/main amd64 dconf-cli amd64 0.36.0-1 [24.0 kB]',
#  '\x1b',
#  '15% [95 dconf-cli 2,766 B/24.0 kB 12%]                           2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:96 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 desktop-file-utils amd64 0.24-1ubuntu3 [50.6 kB]',
#  '\x1b',
#  '15% [96 desktop-file-utils 981 B/50.6 kB 2%]                     2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:97 http://archive.ubuntu.com/ubuntu focal/main amd64 dns-root-data all 2019052802 [5,300 B]',
#  '\x1b',
#  '15% [97 dns-root-data 801 B/5,300 B 15%]                         2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:98 http://archive.ubuntu.com/ubuntu focal/main amd64 libidn11 amd64 1.33-2.2ubuntu2 [46.2 kB]',
#  '\x1b',
#  '15% [98 libidn11 852 B/46.2 kB 2%]                               2,561 kB/s 55s\x1b\x1b',
#  '15% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:99 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dnsmasq-base amd64 2.80-1.1ubuntu1.7 [315 kB]',
#  '\x1b',
#  '15% [99 dnsmasq-base 5,058 B/315 kB 2%]                          2,561 kB/s 55s\x1b\x1b',
#  '15% [Connecting to archive.ubuntu.com (91.189.91.39)]            2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:100 http://archive.ubuntu.com/ubuntu focal/main amd64 xml-core all 0.18+nmu1 [21.6 kB]',
#  '\x1b',
#  '15% [100 xml-core 13.8 kB/21.6 kB 64%]                           2,561 kB/s 55s\x1b\x1b',
#  '15% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:101 http://archive.ubuntu.com/ubuntu focal/main amd64 sgml-data all 2.0.11 [171 kB]',
#  '\x1b',
#  '15% [101 sgml-data 2,533 B/171 kB 1%]                            2,561 kB/s 55s\x1b\x1b',
#  '16% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:102 http://archive.ubuntu.com/ubuntu focal/main amd64 docbook-xml all 4.5-9 [71.2 kB]',
#  '\x1b',
#  '16% [102 docbook-xml 0 B/71.2 kB 0%]                             2,561 kB/s 55s\x1b\x1b',
#  '16% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:103 http://archive.ubuntu.com/ubuntu focal/main amd64 hunspell-en-us all 1:2018.04.16-1 [170 kB]',
#  '\x1b',
#  '16% [103 hunspell-en-us 740 B/170 kB 0%]                         2,561 kB/s 55s\x1b\x1b',
#  '16% [Working]                                                    2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:104 http://archive.ubuntu.com/ubuntu focal/main amd64 libhunspell-1.7-0 amd64 1.7.0-2build2 [147 kB]',
#  '\x1b',
#  '16% [104 libhunspell-1.7-0 0 B/147 kB 0%]                        2,561 kB/s 55s\x1b\x1b',
#  '16% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:105 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libenchant-2-2 amd64 2.2.8-1ubuntu0.20.04.1 [45.6 kB]',
#  '\x1b',
#  '16% [105 libenchant-2-2 1,904 B/45.6 kB 4%]                      2,561 kB/s 55s\x1b\x1b',
#  '16% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:106 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 enchant-2 amd64 2.2.8-1ubuntu0.20.04.1 [12.1 kB]',
#  '\x1b',
#  '16% [106 enchant-2 2,491 B/12.1 kB 21%]                          2,561 kB/s 55s\x1b\x1b',
#  '16% [Waiting for headers]                                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:107 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-base amd64 1:22.2.7+dfsg-1ubuntu0.2 [8,062 kB]',
#  '\x1b',
#  '16% [107 erlang-base 7,030 B/8,062 kB 0%]                        2,561 kB/s 55s\x1b',
#  '                                                                               ',
#  'Get:108 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-dev amd64 1:22.2.7+dfsg-1ubuntu0.2 [315 kB]',
#  '\x1b',
#  '20% [108 erlang-dev 129 kB/315 kB 41%]                           2,561 kB/s 51s\x1b\x1b',
#  '20% [Working]                                                    2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:109 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-asn1 amd64 1:22.2.7+dfsg-1ubuntu0.2 [712 kB]',
#  '\x1b',
#  '20% [109 erlang-asn1 0 B/712 kB 0%]                              2,561 kB/s 51s\x1b\x1b',
#  '21% [Working]                                                    2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:110 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-crypto amd64 1:22.2.7+dfsg-1ubuntu0.2 [137 kB]',
#  '\x1b',
#  '21% [110 erlang-crypto 0 B/137 kB 0%]                            2,561 kB/s 51s\x1b\x1b',
#  '21% [Working]                                                    2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:111 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwxbase3.0-0v5 amd64 3.0.4+dfsg-15build1 [982 kB]',
#  '\x1b',
#  '21% [111 libwxbase3.0-0v5 13.8 kB/982 kB 1%]                     2,561 kB/s 51s\x1b\x1b',
#  '21% [111 libwxbase3.0-0v5 678 kB/982 kB 69%]                     2,561 kB/s 51s\x1b\x1b',
#  '21% [Working]                                                    2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:112 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libnotify4 amd64 0.7.9-1ubuntu3.20.04.2 [19.5 kB]',
#  '\x1b',
#  '21% [112 libnotify4 0 B/19.5 kB 0%]                              2,561 kB/s 51s\x1b\x1b',
#  '21% [Working]                                                    2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:113 http://archive.ubuntu.com/ubuntu focal/universe amd64 libwxgtk3.0-gtk3-0v5 amd64 3.0.4+dfsg-15build1 [4,359 kB]',
#  '\x1b',
#  '21% [113 libwxgtk3.0-gtk3-0v5 0 B/4,359 kB 0%]                   2,561 kB/s 51s\x1b',
#  '                                                                               ',
#  'Get:114 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 erlang-wx amd64 1:22.2.7+dfsg-1ubuntu0.2 [2,793 kB]',
#  '\x1b',
#  '23% [114 erlang-wx 60.3 kB/2,793 kB 2%]                          2,561 kB/s 49s\x1b\x1b',
#  '25% [Working]                                                    2,561 kB/s 48s\x1b',
#  '                                                                               ',
#  'Get:115 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 erlang-debugger amd64 1:22.2.7+dfsg-1ubuntu0.2 [378 kB]',
#  '\x1b',
#  '25% [115 erlang-debugger 0 B/378 kB 0%]                          2,561 kB/s 48s\x1b\x1b',
#  '25% [Working]                                                    2,561 kB/s 48s\x1b',
#  '                                                                               ',
#  'Get:116 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-mnesia amd64 1:22.2.7+dfsg-1ubuntu0.2 [716 kB]',
#  '\x1b',
#  '25% [116 erlang-mnesia 12.3 kB/716 kB 2%]                        2,561 kB/s 48s\x1b\x1b',
#  '25% [Working]                                                    2,561 kB/s 47s\x1b',
#  '                                                                               ',
#  'Get:117 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 erlang-runtime-tools amd64 1:22.2.7+dfsg-1ubuntu0.2 [182 kB]',
#  '\x1b',
#  '26% [117 erlang-runtime-tools 24.6 kB/182 kB 13%]                2,561 kB/s 47s\x1b\x1b',
#  ...]

# %% [markdown]
# **Ejemplo 1**

# %% [markdown]
# Escribir un programa en Erlang que genere dos procesos concurrentes uno que sume y otro que reste dos números.

# %%
# %%writefile arithmetic.erl
#
# -module(arithmetic).
# -export([start/0, sum/2, subtract/2]).
#
# start() ->
#     spawn(arithmetic, sum, [8, 2]),
#     spawn(arithmetic, subtract, [8, 2]).
#
# sum(A, B) ->
#     Result = A + B,
#     io:format("Sum result: ~w~n", [Result]).
#
# subtract(A, B) ->
#     Result = A - B,
#     io:format("Subtraction result: ~w~n", [Result]).
# Out:
# Overwriting arithmetic.erl

# %%
# !erlc arithmetic.erl
# !time erl -noshell -s arithmetic start -s init stop
# Out:
# Sum result: 10
# Subtraction result: 6
#
# real	0m1.349s
# user	0m0.274s
# sys	0m0.032s

# %% [markdown]
# **Ejemplo 2**

# %% [markdown]
#  Implementar un programa en Erlang que permita calcular el mínimo y el máximo de una lista de números de forma concurrente. El programa debe crear dos procesos: uno para calcular el mínimo y otro para calcular el máximo. Cada proceso debe realizar sus cálculos de manera independiente y enviar el resultado al proceso principal. El proceso principal debe imprimir los valores mínimo y máximo una vez que los haya recibido de los procesos secundarios.

# %%
# %%writefile min_max_concurrent.erl
# -module(min_max_concurrent).
#
# % Exportamos la función calculate_min_max/1 desde el módulo min_max_concurrent.
# % El número 1 entre paréntesis indica que la función tiene un aridad de 1, lo que significa que toma un argumento.
# -export([calculate_min_max/1, start/0]).
#
# % Función principal para calcular el mínimo y el máximo de una lista de forma concurrente (uso de cláusulas).
# calculate_min_max(List) ->
#     % Obtenemos el identificador del proceso principal.
#     ParentPid = self(),
#     % Creamos dos procesos secundarios para calcular el mínimo y el máximo.
#     % Utilizamos spawn para crear procesos y fun para definir funciones anónimas
#     spawn(fun() -> calculate_min(ParentPid, List) end),
#     spawn(fun() -> calculate_max(ParentPid, List) end),
#     % Esperamos a recibir los resultados de los procesos secundarios.
#     receive
#         % Recibimos el mensaje con el mínimo.
#         {min, Min} ->
#             receive
#                 % Recibimos el mensaje con el máximo.
#                 {max, Max} ->
#                     % Imprimimos el valor mínimo.
#                     io:format("Minimum: ~w~n", [Min]),
#                     % Imprimimos el valor máximo.
#                     io:format("Maximum: ~w~n", [Max])
#             end
#     end.
#
# % Función para calcular el mínimo de una lista (uso de cláusulas).
# % Esta función se encarga de recorrer la lista de números y actualizar el mínimo en cada iteración, manteniendo el valor mínimo actualizado hasta ese punto.
# calculate_min(ParentPid, [Head|Tail]) ->
#     % Llamamos a la función auxiliar con el valor mínimo actualizado.
#     calculate_min(ParentPid, Tail, Head).
#
# % Esta función itera sobre la lista de números y actualiza el valor mínimo (MinSoFar) cada vez que encuentra un número menor.
# % Utiliza la recursión para seguir avanzando en la lista hasta llegar al final y enviar el resultado al proceso principal.
# calculate_min(ParentPid, [Head|Tail], MinSoFar) ->
#     % Comparamos el número actual con el mínimo actual.
#     if
#         % Si encontramos un número menor, actualizamos el mínimo.
#         Head < MinSoFar ->
#             calculate_min(ParentPid, Tail, Head);
#         % Si no, continuamos con el mínimo actual.
#         true ->
#             calculate_min(ParentPid, Tail, MinSoFar)
#     end;
#
# % Esta función se ejecuta cuando hemos recorrido toda la lista de números y ya no quedan más elementos para comparar.
# % En este punto, tenemos el valor mínimo final y estamos listos para enviarlo al proceso principal.
# calculate_min(ParentPid, [], Min) ->
#     % Enviamos el resultado al proceso principal.
#     ParentPid ! {min, Min}.
#
# % Función para calcular el máximo de una lista.
# calculate_max(ParentPid, [Head|Tail]) ->
#     % Llamamos a la función auxiliar con el valor máximo actualizado.
#     calculate_max(ParentPid, Tail, Head).
#
# calculate_max(ParentPid, [Head|Tail], MaxSoFar) ->
#     % Comparamos el número actual con el máximo actual.
#     if
#         % Si encontramos un número mayor, actualizamos el máximo.
#         Head > MaxSoFar ->
#             calculate_max(ParentPid, Tail, Head);
#         % Si no, continuamos con el máximo actual.
#         true ->
#             calculate_max(ParentPid, Tail, MaxSoFar)
#     end;
# calculate_max(ParentPid, [], Max) ->
#     % Enviamos el resultado al proceso principal.
#     ParentPid ! {max, Max}.
#
# start() ->
#   min_max_concurrent:calculate_min_max([5, 8, 2, 1, 9, 4, 12, 1]).
# Out:
# Overwriting min_max_concurrent.erl

# %% [markdown]
# Para efectos del tutorial, este ejemplo se realizó en Repl.it, una plataforma en línea que proporciona un entorno de desarrollo integrado (IDE) basado en la nube para ejecutar y programar en varios lenguajes de programación, incluido Erlang. Aquí se tiene cómo ejecutar el código anterior en el shell de Repl.it para Erlang:
#
# 1.   Abrir un terminal o una línea de comandos en Repl.it.
# 2.   Iniciar el shell de Erlang escribiendo '*erl*' y presionando Enter.
# 3.   En el shell de Erlang, compila el código escribiendo '*c(min_max_concurrent).*' y presionando Enter.
# 4.   Ejecutar el cálculo del mínimo y máximo de una lista llamando a la función *min_max_concurrent:calculate_min_max/1* con una lista de números como argumento. Por ejemplo, escribir '*min_max_concurrent:calculate_min_max([5, 8, 2, 1, 9, 4, 12, 1]).*' y posteriormente presionar Enter.
#
# El programa hallará el valor mínimo y el valor máximo de la lista de forma concurrente y los mostrará en consola, de la siguiente manera:

# %%
# !erlc min_max_concurrent.erl
# !time erl -noshell -s min_max_concurrent start -s init stop
# Out:
# Minimum: 1
# Maximum: 12
#
# real	0m1.343s
# user	0m0.336s
# sys	0m0.041s

# %%
C: erl
Erlang/OTP 24 [erts-12.3.2.5] [source] [64-bit] [smp:16:1] [ds:16:1:10] [async-threads:1] [jit]

Eshell V12.3.2.5  (abort with ^G)
1> c(min_max_concurrent).
{ok,min_max_concurrent}
2> min_max_concurrent:calculate_min_max([5, 8, 2, 1, 9, 4, 12, 1]).
Minimum: 1
Maximum: 12
# Out:
#   File "<ipython-input-2-ce3c7c54b543>", line 2
#     Erlang/OTP 24 [erts-12.3.2.5] [source] [64-bit] [smp:16:1] [ds:16:1:10] [async-threads:1] [jit]
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Ejemplo 3**

# %% [markdown]
# Implementar un programa en erlang que permita organizar una cierta lista dada utilizando el algoritmo merge sort usando concurrencia, utilizando recursión. En este caso cada vez que la lista se divida en dos se pueden crear nuevos procesos. Luego el primero proceso es el que debe imprimir la lista.
#
# Plus: Implementar un programa que verifique el tiempo que toma en realizar el merge sort con y sin concurrencia

# %%
# %%writefile parallelMergeSort.erl
# -module(parallelMergeSort).
# -import(io,[fwrite/1]).
# -export([ms/1, pms/1, p_ms/2, start/0]).
#
# start() ->
#     seed(),
#     List = create_list( 50000, 100000 ),
#     { Time1, _ } = timer:tc( parallelMergeSort, ms, [List] ),
#     io:format( "Merge sort took ~p seconds.~n", [Time1 / 1000000] ),
#     { Time2, _ } = timer:tc( parallelMergeSort, pms, [List] ),
#     io:format( "Parallel merge sort took ~p seconds.~n", [Time2 / 1000000] ).
#
# %% seed( ) will seed the random number generator.
# seed( ) ->
#     rand:seed( exsss, { erlang:phash2( node( ) ), erlang:monotonic_time( ), erlang:unique_integer( ) } ).
#
# %% create_list( Length, Max ) returns a list with Length items in it, all of which are random numbers between 1 and Max.
# create_list( 0, _ ) -> [];
# create_list( Length, Max ) ->
#     [ rand:uniform( Max ) | create_list( Length - 1, Max ) ].
#
# % SEPARATE INTO TWO LISTS USING N AS THE LENGTH OF THE FIRST LIST,
# % AND THUS, THE SECOND LIST WILL HAVE length(L)-N elements
#
# % case we say the length of the list1 is 0
# sep(L, 0) ->
# 	{[], L};
#
# sep([H|T],N) ->
#    {Lleft, Lright} = sep(T,N-1),
#    	{append([H],Lleft), Lright}.
#
# append(L1,L2) ->
# 	L1++L2.
#
#
# % MERGE RETURNING SORTED LIST OF TWO LISTS
# merge(L1,L2) ->
# 	merge(L1,L2,[]).
#
# merge([], [], RESULT_LIST) -> RESULT_LIST;
# merge([], SECOND_LIST, RESULT_LIST) -> append(RESULT_LIST, SECOND_LIST);
# merge(FIRST_LIST, [], RESULT_LIST) -> append(RESULT_LIST, FIRST_LIST);
# merge([H1|FIRST_LIST], [H2|SECOND_LIST], RESULT_LIST) ->
# 	if 	H1 < H2 ->
# 			merge(FIRST_LIST, [H2|SECOND_LIST], append(RESULT_LIST, [H1]));
# 		true ->
# 			merge([H1|FIRST_LIST], SECOND_LIST, append(RESULT_LIST, [H2]))
# 	end.
#
# % MERGE SORT IMPLEMENTATION
# ms([]) -> [];
# ms([X]) -> [X];
# ms(L) ->
#    {L1, L2} = sep(L, length(L) div 2),
#    merge(ms(L1), ms(L2)).
#
#
# % PARALLEL VERSION OF MERGE SORT
# rcvp(Pid) ->
# 	receive
# 		{Pid, L} -> L
# 	end.
#
# pms(L) ->
# 	Pid = spawn(parallelMergeSort, p_ms, [self(), L]),
#   rcvp(Pid).
#
# p_ms(Pid, L) when length(L) < 100 ->
#   Pid ! {self(), ms(L)}; %Do mergesort
# p_ms(Pid, L) -> %Else, if the length is "long", spawn processes
# 	{Lleft, Lright} = sep(L, length(L) div 2),
#     Pid1 = spawn(parallelMergeSort, p_ms, [self(), Lleft]),
#     Pid2 = spawn(parallelMergeSort, p_ms, [self(), Lright]),
#     L1 = rcvp(Pid1),
#     L2 = rcvp(Pid2),
#     Pid ! {self(), merge(L1,L2)}. %Send to father the merged lists
# Out:
# Overwriting parallelMergeSort.erl

# %%
# !erlc parallelMergeSort.erl
# !time erl -noshell -s parallelMergeSort start -s init stop
# Out:
# Merge sort took 8.129044 seconds.
# Parallel merge sort took 7.619456 seconds.
#
# real	0m17.067s
# user	0m25.390s
# sys	0m1.500s
